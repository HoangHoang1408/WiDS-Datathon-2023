# %%
import numpy as np
import optuna
from optuna.integration.catboost import CatBoostPruningCallback

import catboost as cb
from sklearn.datasets import load_breast_cancer
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


def objective(trial: optuna.Trial):
    data, target = load_breast_cancer(return_X_y=True)
    train_x, valid_x, train_y, valid_y = train_test_split(data, target, test_size=0.25)

    param = {
        "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1, log=True),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
        "eval_metric": "Accuracy",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1, log=True)

    gbm = cb.CatBoostClassifier(**param)

    pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
    gbm.fit(
        train_x,
        train_y,
        eval_set=[(valid_x, valid_y)],
        verbose=0,
        early_stopping_rounds=100,
        callbacks=[pruning_callback],
    )

    # evoke pruning manually.
    pruning_callback.check_pruned()

    preds = gbm.predict(valid_x)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(valid_y, pred_labels)

    return accuracy


if __name__ == "__main__":
    study = optuna.create_study(
        pruner=optuna.pruners.MedianPruner(n_warmup_steps=5), direction="maximize"
    )
    study.optimize(objective, n_trials=100, timeout=600)

    print("Number of finished trials: {}".format(len(study.trials)))

    print("Best trial:")
    trial = study.best_trial

    print("  Value: {}".format(trial.value))

    print("  Params: ")
    for key, value in trial.params.items():
        print("    {}: {}".format(key, value))
# Out:
# [I 2023-02-04 10:18:22,964] A new study created in memory with name: no-name-924d56df-bcb6-4ea3-8edc-bbb909cd42ed
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:23,342] Trial 0 finished with value: 0.951048951048951 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.02834180453406305, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.17094393350868958}. Best is trial 0 with value: 0.951048951048951.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:23,726] Trial 1 finished with value: 0.9790209790209791 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08105970370327391, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9790209790209791.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:23,889] Trial 2 finished with value: 0.9300699300699301 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.05667370879165474, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 1 with value: 0.9790209790209791.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:24,179] Trial 3 finished with value: 0.9300699300699301 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.014135440737579108, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.914073023391158}. Best is trial 1 with value: 0.9790209790209791.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:24,609] Trial 4 finished with value: 0.9790209790209791 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.06603593792436477, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6
ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:31,808] Trial 69 pruned. Trial was pruned at iteration 48.
# [I 2023-02-04 10:18:31,830] Trial 70 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:31,860] Trial 71 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:31,882] Trial 72 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:31,904] Trial 73 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,054] Trial 74 pruned. Trial was pruned at iteration 111.
# [I 2023-02-04 10:18:32,083] Trial 75 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,188] Trial 76 finished with value: 0.986013986013986 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08399575942634516, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 35 with value: 0.986013986013986.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:32,206] Trial 77 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,226] Trial 78 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,385] Trial 79 finished with value: 0.972027972027972 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.08268585244391154, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.37579384255610704}. Best is trial 35 with value: 0.986013986013986.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:32,401] Trial 80 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,419] Trial 81 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,442] Trial 82 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,498] Trial 83 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,786] Trial 84 pruned. Trial was pruned at iteration 106.
# [I 2023-02-04 10:18:32,802] Trial 85 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,827] Trial 86 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:32,852] Trial 87 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:33,023] Trial 88 finished with value: 0.965034965034965 and parameters: {'objective': 'Logloss', 'colsample_bylevel': 0.03670565018806441, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 35 with value: 0.986013986013986.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:33,112] Trial 89 pruned. Trial was pruned at iteration 47.
# [I 2023-02-04 10:18:33,137] Trial 90 pruned. Trial was pruned at iteration 12.
# [I 2023-02-04 10:18:33,496] Trial 91 finished with value: 0.993006993006993 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07884832626557377, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 91 with value: 0.993006993006993.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:33,527] Trial 92 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:34,028] Trial 93 finished with value: 0.986013986013986 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08547667019969091, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 91 with value: 0.993006993006993.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:34,379] Trial 94 finished with value: 0.972027972027972 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.08588782425728479, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 91 with value: 0.993006993006993.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:34,691] Trial 95 finished with value: 0.9790209790209791 and parameters: {'objective': 'CrossEntropy', 'colsample_bylevel': 0.07853681534342226, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 91 with value: 0.993006993006993.
# /var/folders/sx/c_sxyj753hx_sjy7c76rlnt00000gn/T/ipykernel_7095/2097341404.py:46: ExperimentalWarning: CatBoostPruningCallback is experimental (supported from v3.0.0). The interface can change in the future.
#   pruning_callback = CatBoostPruningCallback(trial, "Accuracy")
# [I 2023-02-04 10:18:34,883] Trial 96 pruned. Trial was pruned at iteration 56.
# [I 2023-02-04 10:18:34,914] Trial 97 pruned. Trial was pruned at iteration 5.
# [I 2023-02-04 10:18:35,071] Trial 98 pruned. Trial was pruned at iteration 56.
# [I 2023-02-04 10:18:35,096] Trial 99 pruned. Trial was pruned at iteration 5.
# Number of finished trials: 100
# Best trial:
#   Value: 0.993006993006993
#   Params:
#     objective: CrossEntropy
#     colsample_bylevel: 0.07884832626557377
#     depth: 6
#     boosting_type: Ordered
#     bootstrap_type: MVS

# %%
import catboost
import optuna
catboost.__version__
optuna.__version__
# Out:
# '3.0.5'
