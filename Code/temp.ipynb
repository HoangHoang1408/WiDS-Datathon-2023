# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

pd.options.display.max_columns = None
pd.options.display.max_rows = 250

# %%
df = pd.read_csv('../Data/train_data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Columns: 246 entries, index to wind-vwnd-925-2010-20
# dtypes: float64(240), int64(4), object(2)
# memory usage: 705.2+ MB

# %%
df.head(10)
# Out:
#    index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      0  0.0  0.833333    9/1/14                              237.00
# 1      1  0.0  0.833333    9/2/14                              228.90
# 2      2  0.0  0.833333    9/3/14                              220.69
# 3      3  0.0  0.833333    9/4/14                              225.28
# 4      4  0.0  0.833333    9/5/14                              237.24
# 5      5  0.0  0.833333    9/6/14                              237.87
# 6      6  0.0  0.833333    9/7/14                              236.36
# 7      7  0.0  0.833333    9/8/14                              233.36
# 8      8  0.0  0.833333    9/9/14                              233.82
# 9      9  0.0  0.833333   9/10/14                              229.74
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                     29.02                     31.64
# 1                     29.02                     31.64
# ...

# %%
def df_info(df:pd.DataFrame):
  nan_count = df.isna().sum()
  df_info = pd.DataFrame({
    'nan_count':nan_count,
    'nan_percent': np.round(nan_count*100/len(df),4),
    'unique_count': df.nunique(), 
    'dtype': df.dtypes
  })
  return df_info

# %%
df_info(df)
# Out:
#                                           nan_count  nan_percent  \
# index                                             0       0.0000
# lat                                               0       0.0000
# lon                                               0       0.0000
# startdate                                         0       0.0000
# contest-pevpr-sfc-gauss-14d__pevpr                0       0.0000
# nmme0-tmp2m-34w__cancm30                          0       0.0000
# nmme0-tmp2m-34w__cancm40                          0       0.0000
# nmme0-tmp2m-34w__ccsm30                       15934       4.2408
# nmme0-tmp2m-34w__ccsm40                           0       0.0000
# nmme0-tmp2m-34w__cfsv20                           0       0.0000
# nmme0-tmp2m-34w__gfdlflora0                       0       0.0000
# nmme0-tmp2m-34w__gfdlflorb0                       0       0.0000
# nmme0-tmp2m-34w__gfdl0                            0       0.0000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Columns: 246 entries, index to wind-vwnd-925-2010-20
# dtypes: float64(240), int64(4), object(2)
# memory usage: 705.2+ MB

# %%
temp = df_info(df)

# %%
null_contained_cols = temp[temp['nan_count']>0].index
temp.loc[null_contained_cols]
# Out:
#                          nan_count  nan_percent  unique_count    dtype
# nmme0-tmp2m-34w__ccsm30      15934       4.2408          3840  float64
# nmme-tmp2m-56w__ccsm3        10280       2.7360          5000  float64
# nmme-prate-34w__ccsm3         8738       2.3256         10139  float64
# nmme0-prate-56w__ccsm30      15934       4.2408          5716  float64
# nmme0-prate-34w__ccsm30      15934       4.2408          5712  float64
# nmme-prate-56w__ccsm3        10280       2.7360         10008  float64
# nmme-tmp2m-34w__ccsm3         8738       2.3256          4810  float64
# ccsm30                       15934       4.2408          3833  float64

# %%
df.columns = df.columns.str.replace('-','_')

# %%
index = 'index'
lat = 'lat'
lon = 'lon'
startdate = 'startdate'
contest_pevpr_sfc_gauss_14d__pevpr = 'contest_pevpr_sfc_gauss_14d__pevpr'
nmme0_tmp2m_34w__cancm30 = 'nmme0_tmp2m_34w__cancm30'
wind_vwnd_925_2010_18 = 'wind_vwnd_925_2010_18'
wind_vwnd_925_2010_19 = 'wind_vwnd_925_2010_19'
wind_vwnd_925_2010_20 = 'wind_vwnd_925_2010_20'


# created cols
year = 'year'
month = 'month'
day = 'day'

# %%
def get_column_data(df:pd.DataFrame, column_name:str, start_index:int=0, end_index:int=10):
  return df[column_name][start_index:end_index]

def plot_line(df:pd.DataFrame, column_name:list[str], start_index:int=0, end_index:int=50):
  plt.figure(figsize=(20,8))
  for col in column_name:
    sns.lineplot(x=startdate, y=col, data=df.iloc[start_index:end_index], label=col)
  plt.xticks(rotation=90)
  plt.ylabel('Values')
  plt.xlabel('Date')
  plt.legend()
  plt.show()

# %%
df['year'] = df[startdate].str.split('/').str[2].astype(int)
df['month'] = df[startdate].str.split('/').str[0].astype(int)
df['day'] = df[startdate].str.split('/').str[1].astype(int)

# %%
plot_line(
  df=df,
  column_name=[
    cancm30,
    cancm40,
    ccsm30,
    ccsm40,
    cfsv20,
    gfdlflora0,
    gfdlflorb0,
    gfdl0,
    nasa0,
    nmme0mean,
  ],
  start_index=350,
  end_index=450
)

# %%
df[[
    cancm30,
    cancm40,
    ccsm30,
    ccsm40,
    cfsv20,
    gfdlflora0,
    gfdlflorb0,
    gfdl0,
    nasa0,
    nmme0mean,
]].head(10)
# Out:
#    cancm30  cancm40  ccsm30  ccsm40  cfsv20  gfdlflora0  gfdlflorb0  gfdl0  \
# 0    30.18    32.86   28.85   30.73   29.33       31.66       31.45  31.33
# 1    30.18    32.86   28.85   30.73   29.33       31.66       31.45  31.33
# 2    30.18    32.86   28.85   30.73   29.33       31.66       31.45  31.33
# 3    30.18    32.86   28.85   30.73   29.33       31.66       31.45  31.33
# 4    30.18    32.86   28.85   30.73   29.33       31.66       31.45  31.33
# 5    29.02    31.64   29.57   30.73   29.71       31.52       31.68  30.56
# 6    29.02    31.64   29.57   30.73   29.71       31.52       31.68  30.56
# 7    29.02    31.64   29.57   30.73   29.71       31.52       31.68  30.56
# 8    29.02    31.64   29.57   30.73   29.71       31.52       31.68  30.56
# 9    29.02    31.64   29.57   30.73   29.71       31.52       31.68  30.56
#
#    nasa0  nmme0mean
# 0  29.51      30.65
# 1  29.51      30.65
# 2  29.51      30.65
# 3  29.51      30.65
# 4  29.51      30.65
# ...

# %%
# fill some missing values of one type model predict with mean of all models

# nmme0-tmp2m-34w__ccsm30
# nmme0-prate-34w__ccsm30
# nmme0-prate-56w__ccsm30
# nmme-tmp2m-56w__ccsm3
# nmme-tmp2m-34w__ccsm3
# nmme-prate-34w__ccsm3
# nmme-prate-56w__ccsm3
# ccsm30

df[nmme0_tmp2m_34w__ccsm30] = df[nmme0_tmp2m_34w__ccsm30].fillna(df[nmme0_tmp2m_34w__nmme0mean])
df[nmme0_prate_34w__ccsm30] = df[nmme0_prate_34w__ccsm30].fillna(df[nmme0_prate_34w__nmme0mean])
df[nmme0_prate_56w__ccsm30] = df[nmme0_prate_56w__ccsm30].fillna(df[nmme0_prate_56w__nmme0mean])
df[nmme_tmp2m_34w__ccsm3] = df[nmme_tmp2m_34w__ccsm3].fillna(df[nmme_tmp2m_34w__nmmemean])
df[nmme_tmp2m_56w__ccsm3] = df[nmme_tmp2m_56w__ccsm3].fillna(df[nmme_tmp2m_56w__nmmemean])
df[nmme_prate_34w__ccsm3] = df[nmme_prate_34w__ccsm3].fillna(df[nmme_prate_34w__nmmemean])
df[nmme_prate_56w__ccsm3] = df[nmme_prate_56w__ccsm3].fillna(df[nmme_prate_56w__nmmemean])
df[ccsm30] = df[ccsm30].fillna(df[nmme0mean])

# %%
temp = df.isna().sum() 
temp[temp>0]
# Out:
# Series([], dtype: int64)

# %%
df.drop(columns=[
  startdate,
  index,
], inplace=True)

# %%
df[day].value_counts().sort_index().plot(kind='bar', figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
df[month].value_counts().sort_index().plot(kind='bar', figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
df[year].value_counts().sort_index().plot(kind='bar', figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
month_and_day = 'month_and_day'
df[month_and_day] = df[month].astype(str) + '-' + df[day].astype(str)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from category_encoders import TargetEncoder

from sklearn.decomposition import PCA

from xgboost import XGBRegressor

# %%
target = contest_tmp2m_14d__tmp2m
X, y = df.drop(columns=[target]), df[target]

# %%
# encoded climateregions__climateregion
target_encoder = TargetEncoder()
X[climateregions__climateregion] = target_encoder.fit_transform(X[climateregions__climateregion], y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/category_encoders/target_encoder.py:122: FutureWarning: Default parameter min_samples_leaf will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter min_samples_leaf will change in version 2.6."
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/category_encoders/target_encoder.py:127: FutureWarning: Default parameter smoothing will change in version 2.6.See https://github.com/scikit-learn-contrib/category_encoders/issues/327
#   warnings.warn("Default parameter smoothing will change in version 2.6."

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, shuffle=True, stratify=df[month_and_day])
X_train.drop(columns=[month_and_day], inplace=True)
X_test.drop(columns=[month_and_day], inplace=True)

# %%
X.shape, y.shape, X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((375734, 247), (375734,), (338160, 246), (37574, 246), (338160,), (37574,))

# %%
base_model = XGBRegressor(
  random_state=42,
)
base_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=42, ...)

# %%
y_pred = base_model.predict(X_test)
mean_squared_error(y_test, y_pred, squared=False)
# Out:
# 0.7179961194283399

# %%
# plot feature importance
plt.figure(figsize=(20,200))
sns.barplot(x=base_model.feature_importances_, y=X_train.columns)
plt.show()

# %%
# load test data
test_df = pd.read_csv('../Data/test_data.csv')
submit_index = test_df[index]

# %%
# preprocess test data
test_df['year'] = test_df[startdate].str.split('/').str[2].astype(int)
test_df['month'] = test_df[startdate].str.split('/').str[0].astype(int)
test_df['day'] = test_df[startdate].str.split('/').str[1].astype(int)

test_df[climateregions__climateregion] = target_encoder.transform(test_df[climateregions__climateregion])

test_df.drop(columns=[
  startdate,
  index,
], inplace=True)

# %%
test_df.columns = test_df.columns.str.replace('-','_')

# %%
X_test_submit = test_df
y_pred_submit = base_model.predict(X_test_submit)
df_submit = pd.DataFrame({
  'contest-tmp2m-14d__tmp2m': y_pred_submit,
  'index': submit_index,
}).to_csv('submission.csv', index=False)
